# %%
# !pip install pytesseract opencv-python-headless pillow
# Out:
# Requirement already satisfied: pytesseract in /Users/pranaysinghvi/my-python3-env/lib/python3.12/site-packages (0.3.13)
# Collecting opencv-python-headless
#   Obtaining dependency information for opencv-python-headless from https://files.pythonhosted.org/packages/1c/9b/583c8d9259f6fc19413f83fd18dd8e6cbc8eefb0b4dc6da52dd151fe3272/opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: pillow in /Users/pranaysinghvi/my-python3-env/lib/python3.12/site-packages (10.2.0)
# Requirement already satisfied: packaging>=21.3 in /Users/pranaysinghvi/my-python3-env/lib/python3.12/site-packages (from pytesseract) (23.2)
# Requirement already satisfied: numpy>=1.21.2 in /Users/pranaysinghvi/my-python3-env/lib/python3.12/site-packages (from opencv-python-headless) (1.26.4)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 3.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.10.0.84
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import cv2
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt

# %%
pytesseract.pytesseract.tesseract_cmd = r'/opt/homebrew/Cellar/tesseract/5.4.1/bin/tesseract'

# %%
# Load the image
image_path = "doc2.jpg"  # Replace with your image file path
image = cv2.imread(image_path)

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Use Tesseract to extract text from the image
text = pytesseract.image_to_string(gray_image)

# %%
# Display the original image
plt.figure(figsize=(8, 8))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Handwritten Text Recognition')
plt.show()

# Print the extracted text
print("Extracted Text:")
print(text)
# Out:
# Extracted Text:
# Smile Designing | Tee itenin,
# gning | Teeth Whitening THE QJHITE TUSK
#
# Dental Implants | General Dentistry
# @@/whitetuskdental
#
# bon Pe Sack Banrsaae :
# inne
#
# | : eb. mentun eo
# | Ses ae
# Tab- EnesPlam
#
# " ae
#
# ee
#
# befor oe fare Ao
# "at ee Oe coe
